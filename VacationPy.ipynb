# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import matplotlib as plt
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID          City Country                 Date      Lat       Lng  \
# 0        0      Thompson      CA  2022-06-09 20:58:20  55.7435  -97.8558
# 1        1  Bahia Blanca      AR  2022-06-09 20:58:24 -38.7196  -62.2724
# 2        2       Kahului      US  2022-06-09 20:58:24  20.8947 -156.4700
# 3        3        Albany      US  2022-06-09 20:55:22  42.6001  -73.9662
# 4        4     Nishihara      JP  2022-06-09 20:58:26  26.1842  127.7558
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     69.96        30          40       11.50
# 1     49.60        39           2       13.13
# 2     81.84        79          10       10.00
# 3     72.95        69          34        1.01
# 4     74.48        94         100       10.36

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
[max(temp,0) for temp in max_temp]
# Out:
# [69.96,
#  49.6,
#  81.84,
#  72.95,
#  74.48,
#  82.47,
#  80.33,
#  75.29,
#  71.85,
#  92.01,
#  75.74,
#  36.73,
#  91.09,
#  73.06,
#  81.77,
#  50.52,
#  38.48,
#  80.62,
#  70.43,
#  44.56,
#  38.8,
#  72.0,
#  105.64,
#  76.23,
#  68.86,
#  95.07,
#  97.88,
#  33.76,
#  58.1,
#  78.76,
#  35.02,
#  55.96,
#  59.92,
#  61.79,
#  71.33,
#  39.33,
#  68.59,
#  75.22,
#  81.63,
#  86.61,
#  41.81,
#  97.14,
#  39.52,
#  53.87,
#  39.31,
#  37.06,
#  73.36,
#  77.63,
#  61.39,
#  44.46,
#  61.79,
#  71.65,
#  78.73,
#  50.43,
#  32.23,
#  60.1,
#  68.56,
#  66.11,
#  44.49,
#  40.17,
#  73.65,
#  82.42,
#  46.26,
#  73.78,
#  64.44,
#  56.32,
#  84.47,
#  87.66,
#  59.5,
#  57.49,
#  71.98,
#  78.48,
#  87.98,
#  51.58,
#  73.67,
#  64.81,
#  89.47,
#  80.83,
#  52.07,
#  79.48,
#  78.93,
#  80.38,
#  79.68,
#  82.81,
#  83.07,
#  80.65,
#  72.12,
#  88.45,
#  89.74,
#  72.18,
#  71.53,
#  63.28,
#  61.95,
#  58.51,
#  52.27,
#  44.55,
#  74.8,
#  82.45,
#  43.61,
#  79.25,
# ...

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
# Set zoom level and center for map
temp_fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

# Assign the heatmap variable.
temp_heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp,0) for temp in max_temp]
                                 ,dissipating=False
                                 ,max_intensity=300
                                 ,point_radius=4)

# Add the heatmap layer.
temp_fig.add_layer(temp_heat_layer)

# Call the figure to plot the data.
temp_fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
humidity_fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
humidity_heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

humidity_fig.add_layer(humidity_heat_layer)
# Call the figure to plot the data.
humidity_fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df['Cloudiness']
cloud_fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
cloud_heat_layer = gmaps.heatmap_layer(locations, weights=clouds,
                                 dissipating=False, 
                                 max_intensity=300, point_radius=4)

cloud_fig.add_layer(cloud_heat_layer)
# Call the figure to plot the data.

cloud_fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
winds = city_data_df['Wind Speed']
wind_fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
wind_heat_layer = gmaps.heatmap_layer(locations, weights=winds,
                                 dissipating=False, 
                                 max_intensity=300, point_radius=4)

wind_fig.add_layer(wind_heat_layer)
# Call the figure to plot the data.

wind_fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)

# %%
preferred_cities_df.dropna(axis=0,how='any',inplace=True)

# %%
preferred_cities_df.isnull().sum()

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")

# %%
hotel_df.head(25)

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
hotel_fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
hotel_heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)
hotel_marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

# Add the temperature heat map and hotel markers
hotel_fig.add_layer(hotel_heat_layer)
hotel_fig.add_layer(hotel_marker_layer)

# Call the figure to plot the data.
hotel_fig
