# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities=[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 645

# %%
import requests
from config import weather_api_key

# %%
lat_list = []

for city in coordinates:
    lat = city[0]
    lon = city[1]

# %%
url = 'https://api.openweathermap.org/data/2.5/weather?'

# for city in coordinates:
#     lat = city[0]
#     lon = city[1]
#     query_url = url + 'lat=' + str(lat) + '&lon=' + str(lon) + '&appid=' + weather_api_key
#     print(query_url)

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+") + '&units=imperial&appid=' + weather_api_key

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | bahia blanca
# Processing Record 3 of Set 1 | kahului
# Processing Record 4 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 1 | nishihara
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | olinda
# Processing Record 10 of Set 1 | sao joao da barra
# Processing Record 11 of Set 1 | soller
# Processing Record 12 of Set 1 | florida
# Processing Record 13 of Set 1 | kimbe
# Processing Record 14 of Set 1 | ust-omchug
# Processing Record 15 of Set 1 | nizwa
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | tual
# Processing Record 18 of Set 1 | lebu
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | wanning
# Processing Record 21 of Set 1 | ponta do sol
# Processing Record 22 of Set 1 | stokmarknes
# ...

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Thompson  55.7435  -97.8558     69.96        30          40
# 1       Bahia Blanca -38.7196  -62.2724     49.60        39           2
# 2            Kahului  20.8947 -156.4700     81.84        79          10
# 3             Albany  42.6001  -73.9662     72.95        69          34
# 4          Nishihara  26.1842  127.7558     74.48        94         100
# 5              Kapaa  22.0752 -159.3190     82.47        70          57
# 6             Olinda  -8.0089  -34.8553     80.33        78          40
# 7  Sao Joao Da Barra -21.6403  -41.0511     75.29        86          37
# 8             Soller  39.7662    2.7152     71.85        73          33
# 9            Florida  28.7505  -82.5001     92.01        67          40
#
#    Wind Speed Country                 Date
# 0       11.50      CA  2022-06-09 20:58:20
# 1       13.13      AR  2022-06-09 20:58:24
# 2       10.00      US  2022-06-09 20:58:24
# ...

# %%
new_column_order = ['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed']

city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#                 City Country                 Date      Lat       Lng  \
# 0           Thompson      CA  2022-06-09 20:58:20  55.7435  -97.8558
# 1       Bahia Blanca      AR  2022-06-09 20:58:24 -38.7196  -62.2724
# 2            Kahului      US  2022-06-09 20:58:24  20.8947 -156.4700
# 3             Albany      US  2022-06-09 20:55:22  42.6001  -73.9662
# 4          Nishihara      JP  2022-06-09 20:58:26  26.1842  127.7558
# 5              Kapaa      US  2022-06-09 20:58:26  22.0752 -159.3190
# 6             Olinda      BR  2022-06-09 20:56:43  -8.0089  -34.8553
# 7  Sao Joao Da Barra      BR  2022-06-09 20:58:27 -21.6403  -41.0511
# 8             Soller      ES  2022-06-09 20:58:28  39.7662    2.7152
# 9            Florida      US  2022-06-09 20:57:00  28.7505  -82.5001
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     69.96        30          40       11.50
# 1     49.60        39           2       13.13
# 2     81.84        79          10       10.00
# ...

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today = time.strftime('%x')
today
# Out:
# '06/09/22'

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
print(index13)
# Out:
# City                      Rikitea
# Country                        PF
# Date          2022-06-09 20:58:30
# Lat                      -23.1203
# Lng                     -134.9692
# Max Temp                    73.06
# Humidity                       56
# Cloudiness                     59
# Wind Speed                  11.48
# Name: 13, dtype: object

# %%
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]

southern_hemi_df.head(3)
# Out:
#                 City Country                 Date      Lat      Lng  Max Temp  \
# 1       Bahia Blanca      AR  2022-06-09 20:58:24 -38.7196 -62.2724     49.60
# 6             Olinda      BR  2022-06-09 20:56:43  -8.0089 -34.8553     80.33
# 7  Sao Joao Da Barra      BR  2022-06-09 20:58:27 -21.6403 -41.0511     75.29
#
#    Humidity  Cloudiness  Wind Speed
# 1        39           2       13.13
# 6        78          40       11.50
# 7        86          37        8.77

# %%
# Extract relevant fields from the DataFrame for plotting.
northern_lats = northern_hemi_df["Lat"]
northern_max_temps = northern_hemi_df["Max Temp"]
northern_humidity = northern_hemi_df["Humidity"]
northern_cloudiness = northern_hemi_df["Cloudiness"]
northern_wind_speed = northern_hemi_df["Wind Speed"]

# Extract relevant fields from the DataFrame for plotting.
southern_lats = southern_hemi_df["Lat"]
southern_max_temps = southern_hemi_df["Max Temp"]
southern_humidity = southern_hemi_df["Humidity"]
southern_cloudiness = southern_hemi_df["Cloudiness"]
southern_wind_speed = southern_hemi_df["Wind Speed"]

# %%
x_values_north = northern_lats
y_values_north = northern_max_temps

plot_linear_regression(x_values_north,y_values_north,
                      'Linear Regression on the Northern Hemisphere for Maximum Temperature',
                      'Max Temp', (0,30))

# %%
x_values_south = southern_lats
y_values_south = southern_max_temps

southern_temp_plot = plot_linear_regression(x_values_south,y_values_south,
                      'Linear Regression on the Southern Hemisphere for Maximum Temperature',
                      'Max Temp', (-55,80))

plt.savefig("weather_data/Fig5_north.png")

# %%
(n_slope, n_intercept, n_r_value, n_p_value, n_std_err) = linregress(northern_lats, northern_max_temps)
(s_slope, s_intercept, s_r_value, s_p_value, s_std_err) = linregress(southern_lats, southern_max_temps)

north_equation = 'y = ' + str(round(n_slope,2)) + 'x + ' + str(round(n_intercept))
south_equation = 'y = ' + str(round(s_slope,2)) + 'x + ' + str(round(s_intercept))

print(north_equation)
print(south_equation)
# Out:
# y = -0.67x + 94
# y = 0.75x + 80

# %%
y_values_north_humidity = northern_humidity

plot_linear_regression(x_values_north,y_values_north_humidity,
                      'Linear Regression on the \n Northern Hemisphere for % Humidity',
                      '% Humidity', (40,10))

plt.savefig("weather_data/Fig5_south.png")

# %%
# # Linear regression on the Northern Hemisphere
# x_values = northern_hemi_df["Lat"]
# y_values = northern_hemi_df["Humidity"]
# # Call the function.
# plot_linear_regression(x_values, y_values,
#                        'Linear Regression on the Northern Hemisphere \
#                         for % Humidity', '% Humidity',(40,10))

# %%
y_values_south_humidity = southern_humidity

plot_linear_regression(x_values_south,y_values_south_humidity,
                      'Linear Regression on the \n Southern Hemisphere for % Humidity',
                      '% Humidity', (-55,20))

# %%
y_values_north_cloudiness = northern_cloudiness

plot_linear_regression(x_values_north,y_values_north_cloudiness,
                      'Linear Regression on the \n Northern Hemisphere for % Cloudiness',
                      '% Cloudiness', (79,12))

# %%
y_values_south_cloudiness = southern_cloudiness

plot_linear_regression(x_values_south,y_values_south_cloudiness,
                      'Linear Regression on the \n Southern Hemisphere for % Cloudiness',
                      '% Cloudiness', (-55,90))

# %%
y_values_north_wind = northern_wind_speed

plot_linear_regression(x_values_north,y_values_north_wind,
                      'Linear Regression on the \n Northern Hemisphere for Wind Speed',
                      'Wind Speed (mph)', (79,12))

# %%
y_values_south_wind = southern_wind_speed

plot_linear_regression(x_values_south,y_values_south_wind,
                      'Linear Regression on the \n Southern Hemisphere for Wind Speed',
                      'Wind Speed (mph)', (-55,22))
